# %% [markdown]
# <a href="https://colab.research.google.com/github/Dakt-98/Project_1/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First project
print("Welcome to the YouTube channel New Generator:")
nick=input("What is your nickname?\n")
chan=input("What is your channel about?\n")
print("You could name your channel" +" ' "+(chan) +" with "+ (nick) + " ' ")
# Out:
# Welcome to the YouTube channel New Generator:
# What is your nickname?
# Dakt
# What is your channel about?
# Programming
# You could name your channel ' Programming with Dakt '
